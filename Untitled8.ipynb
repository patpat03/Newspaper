# %%
from fuzzywuzzy import process, fuzz
import pandas as pd
# Out:
# /usr/local/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
xml = "/Users/Mihir/Downloads/Sample/dronepatents_assignees.csv"
df = pd.read_csv(xml)

# %%
org = df['organization'].tolist()

# %%
temp = []
org = set(org)
for i in org:
    temp.append(i)

# %%
df = {}
for i in org:
    temp.remove(i)
    r = process.extract(i,temp)
    df[i] = r
    temp.append(i)

# %%
print(df)
# Out:
# {'nokia technologies oy': [('singapore technologies aerospace ltd.', 86), ('echostar technologies international corporation', 86), ('general cable technologies corporation', 86), ('horizon technologies consultants, ltd.', 86), ('scope technologies holdings limited', 86)], 'superior communications, inc.': [('nixie labs, inc.', 86), ('lear siegler, inc.', 86), ('northwest uld, inc.', 86), ('metarail, inc.', 86), ('adesa, inc.', 86)], 'arrowonics technologies ltd.': [('edun-eng co., ltd.', 86), ("han's laser technology industry group co., ltd.", 86), ('zerotech (shenzhen) intelligence robot co., ltd.', 86), ('uvify co., ltd.', 86), ('elbit systems ltd.', 86)], 'colorado seminary, which owns and operates the university of denver': [('rutgers, the state university of new jersey', 86), ('national university of defense technology', 86), ('national taiwan university', 86), ('duke university', 86), ('airbus defence and space gmbh', 86)], 'edun-eng co., ltd.': [('rafael advanced defense systems ltd.', 86), ('shenzhen hubsan technology co., ltd.', 86), ("han's laser technology industry group co., ltd.", 86), ('zerotech (shenzhen) intelligence robot co., ltd.', 86), ('st engineering aerospace ltd.', 86)], 'mando corporation': [('georgia tech research corporation', 86), ('northrop grumman corporation', 86), ('inventec appliances (pudong) corporation', 86), ('l-3 communications corporation', 86), ('systems engineering associates corporation', 86)], 'georgia tech research corporation': [('research foundation of the city university of new york', 86), ('panasonic corporation', 86), ('electronics and telecommunifactions research institute', 86), ('intel corporation', 86), ('xcelsis corporation', 86)], 'general atomics': [('general electric company', 86), ('general cable technologies corporation', 86), ('general dynamics corp./convair division', 86), ('continental automotive gmbh', 60), ('zhejiang geely automobile research institute co., ltd.', 60)], 'rafael advanced defense systems ltd.': [('memes associates, ltd.', 86), ('uvify co., ltd.', 86), ('elbit systems ltd.', 86), ('top notch toys ltd. co.', 86), ('nugen systems, inc.', 86)], 'memes associates, ltd.': [('shenzhen hubsan technology co., ltd.', 86), ("han's laser technology industry group co., ltd.", 86), ('zerotech (shenzhen) intelligence robot co., ltd.', 86), ('singapore technologies aerospace ltd.', 86), ('uvify co., ltd.', 86)], 'dcn': [('dcns', 86), ('faro technologies, inc.', 60), ('flirtey holdings, inc.', 60), ('simpsx technologies llc', 60), ('adinte, inc.', 60)], 'shenzhen hubsan technology co., ltd.': [('shenzhen aee technology co., ltd', 90), ('uvify co., ltd.', 86), ('elbit systems ltd.', 86), ('top notch toys ltd. co.', 86), ('tbs avionics co. ltd.', 86)], 'balyo': [('nippon shokubal co., ltd.', 64), ('orbital australia pty ltd', 54), ('kimberly-clark worldwide, inc.', 54), ('aeryon labs inc.', 54), ('chang chun petrochemical co., ltd.', 54)], 'nixie labs, inc.': [('riderless technologies inc.', 86), ('keysight technologies, inc.', 86), ('adesa, inc.', 86), ('mission technologies, inc.', 86), ('rosemount aerospace inc.', 86)], 'king abdullah university of science and technology': [('national taiwan university', 86), ('duke university', 86), ('airbus defence and space gmbh', 86), ('king saud university', 86), ('chaoyang university of technology', 86)], "han's laser technology industry group co., ltd.": [('st engineering aerospace ltd.', 86), ('orbital australia pty ltd', 86), ('uvify co., ltd.', 86), ('israel aircraft industries ltd.', 86), ('elbit systems ltd.', 86)], 'lear siegler, inc.': [('riderless technologies inc.', 86), ('keysight technologies, inc.', 86), ('adesa, inc.', 86), ('advanced ceramic research, inc.', 86), ('kimberly-clark worldwide, inc.', 86)], 'united services automobile association': [('united services automobile association (usaa)', 95), ('the united states of america as represented by the administrator of the national aeronautics and space administr ...

# %%
new = df

# %%
temp = []
fin = []
for i in new.keys():
    temp.append(i)
res = {}
for i in new.keys():
    temp.remove(i)
    res[i] = process.extract(i, temp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/fuzzywuzzy/process.py in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     107         # See if choices is a dictionary-like object.
# --> 108         for key, choice in choices.items():
#     109             processed = pre_processor(processor(choice))
#
# AttributeError: 'list' object has no attribute 'items'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-789ba21ef608> in <module>
#       6 for i in new.keys():
#       7     temp.remove(i)
# ----> 8     res[i] = process.extract(i, temp)
#       9
#
# /usr/local/lib/python3.9/site-packages/fuzzywuzzy/process.py in extract(query, choices, processor, scorer, limit)
#     166     """
#     167     sl = extractWithoutOrder(query, choices, processor, scorer)
# --> 168     return heapq.nlargest(limit, sl, key=lambda i: i[1]) if limit is not None else \
#     169         sorted(sl, key=lambda i: i[1], reverse=True)
#     170
#
# /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/heapq.py in nlargest(n, iterable, key)
#     568     order = -n
#     569     _heapreplace = heapreplace
# --> 570     for elem in it:
#     571         k = key(elem)
#     572         if top < k:
#
# /usr/local/lib/python3.9/site-packages/fuzzywuzzy/process.py in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     115         for choice in choices:
#     116             processed = pre_processor(processor(choice))
# --> 117             score = scorer(processed_query, processed)
#     118             if score >= score_cutoff:
#     119                 yield (choice, score)
#
# /usr/local/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py in WRatio(s1, s2, force_ascii, full_process)
#     287     if try_partial:
#     288         partial = partial_ratio(p1, p2) * partial_scale
# --> 289         ptsor = partial_token_sort_ratio(p1, p2, full_process=False) \
#     290             * unbase_scale * partial_scale
#     291         ptser = partial_token_set_ratio(p1, p2, full_process=False) \
#
# /usr/local/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py in partial_token_sort_ratio(s1, s2, force_ascii, full_process)
#     110     0 and 100 but sorting the token before comparing.
#     111     """
# --> 112     return _token_sort(s1, s2, partial=True, force_ascii=force_ascii, full_process=full_process)
#     113
#     114
#
# /usr/local/lib/python3.9/site-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      36         if args[0] is None or args[1] is None:
#      37             return 0
# ---> 38         return func(*args, **kwargs)
#      39     return decorator
#      40
#
# /usr/local/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py in _token_sort(s1, s2, partial, force_ascii, full_process)
#      94
#      95     if partial:
# ---> 96         return partial_ratio(sorted1, sorted2)
#      97     else:
#      98         return ratio(sorted1, sorted2)
#
# /usr/local/lib/python3.9/site-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      36         if args[0] is None or args[1] is None:
#      37             return 0
# ---> 38         return func(*args, **kwargs)
#      39     return decorator
#      40
#
# /usr/local/lib/python3.9/site-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      27         if args[0] == args[1]:
#      28             return 100
# ---> 29         return func(*args, **kwargs)
#      30     return decorator
#      31
#
# /usr/local/lib/python3.9/site-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      45         if len(args[0]) == 0 or len(args[1]) == 0:
#      46             return 0
# ---> 47         return func(*args, **kwargs)
#      48     return decorator
#      49
#
# /usr/local/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py in partial_ratio(s1, s2)
#      60
#      61         m2 = SequenceMatcher(None, shorter, long_substr)
# ---> 62         r = m2.ratio()
#      63         if r > .995:
#      64             return 100
#
# /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/difflib.py in ratio(self)
#     649         """
#     650
# --> 651         matches = sum(triple[-1] for triple in self.get_matching_blocks())
#     652         return _calculate_ratio(matches, len(self.a) + len(self.b))
#     653
#
# /usr/local/Cellar/python@3.9/3.9.0_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/difflib.py in get_matching_blocks(self)
#     484         while queue:
#     485             alo, ahi, blo, bhi = queue.pop()
# --> 486             i, j, k = x = self.find_longest_match(alo, ahi, blo, bhi)
#     487             # a[alo:i] vs b[blo:j] unknown
#     488             # a[i:i+k] same as b[j:j+k]
#
# KeyboardInterrupt:

# %%
print(res)
# Out:
# {'parrot drones': [('parrot', 90), ('parrott', 79), ('l-3 communications corporation', 46), ('harsco corporation', 45), ('harris corporation', 45)], 'spring communications company l.p.': [('sprint communications company l.p.', 97), ('interstate electronics corporation, a subsidiary of l-3 communications corporation', 86), ('l-3 communications corporation', 67), ('tribune broadcasting company, llc', 59), ('tribune boradcasting company, llc', 59)], 'interstate electronics corporation, a subsidiary of l-3 communications corporation': [('l-3 communications corporation', 90), ('northrop grumman corporation', 86), ('northrop corporation', 86), ('harsco corporation', 86), ('korea advanced institute of science and technology', 86)], 'draganfly innovations inc.': [('dragonfly innovations inc.', 96), ('e-systems, inc.', 86), ('aerovironment, inc.', 47), ('arinc incorporated', 45), ('pusan national university industry-university cooperation foundation', 43)], 'the united states of america as represented by the secretary of the navy': [('the united states of america as represented by the secretary of the army', 97), ('the united states of america as represented by the secretary of the air force', 93), ('united services automobile association', 86), ('united services automobile association (usaa)', 86), ('korea institute of science and technology', 86)], 'parrot': [('parrott', 92), ('faro technologies, inc.', 60), ('harsco corporation', 47), ('ai incorporated', 45), ('northrop grumman corporation', 45)], 'e-systems, inc.': [('airspace systems, inc.', 90), ('parachute systems, inc.', 90), ('dragonfly innovations inc.', 86), ('flir unmanned aerial systems ulc', 86), ('rpx technologies, inc.', 86)], 'dragonfly innovations inc.': [('faro technologies, inc.', 47), ('arinc incorporated', 45), ('l-3 communications corporation', 44), ('pusan national university industry-university cooperation foundation', 43), ('rpx technologies, inc.', 43)], 'pusan national university industry-university cooperation foundation': [('industry-academic cooperation foundation gyeongsang national university', 89), ('harsco corporation', 60), ('harris corporation', 60), ('northrop corporation', 54), ('international business machines corporation', 50)], 'terumo kabushiki kaisha': [('trio kabushiki kaisha', 91), ('international business machines corporation', 43), ('airbus helicopters', 42), ('united services automobile association', 36), ('united services automobile association (usaa)', 36)], 'airbus helicopters': [('airbus helicopters deutschland gmbh', 90), ('eurocopter', 63), ('ai incorporated', 55), ('airspace systems, inc.', 50), ('arinc incorporated', 50)], 'the united states of america as represented by the secretary of the air force': [('the united states of america as represented by the secretary of the army', 94), ('united services automobile association', 86), ('korea advanced institute of science and technology', 86), ('united services automobile association (usaa)', 86), ('korea institute of science and technology', 86)], 'ai incorporated': [('arinc incorporated', 91), ('harris corporation', 67), ('l-3 communications corporation', 66), ('northrop grumman corporation', 62), ('harsco corporation', 61)], 'northrop grumman corporation': [('northrop corporation', 95), ('harsco corporation', 86), ('international business machines corporation', 86), ('international buisiness machines corporation', 86), ('harris corporation', 86)], 'northrop corporation': [('international business machines corporation', 86), ('international buisiness machines corporation', 86), ('l-3 communications corporation', 86), ('harris corporation', 74), ('harsco corporation', 72)], 'the united states of america as represented by the secretary of the army': [('united services automobile association', 86), ('united services automobile association (usaa)', 86), ('korea institute of science and technology', 86), ('flir unmanned aerial systems as', 86), ('flir unmanned aerial systems ulc', 40)], ...

# %%
one = []
two = []
three = []
for i in df.keys():
    x = []
    x.append(i)
    x.append(df[i])
    one.append(x)

# %%
dataframe=pd.DataFrame(one, columns=["company", 'match'])

# %%
compression_opts = dict(method='zip',
                         archive_name='companiesfin.csv')  
dataframe.to_csv('companiesfin.zip', index=False,
           compression=compression_opts)

# %%
temp = df

# %%
for i in temp:
    if(temp[i] == None):
        temp[i] = i

# %%
print(temp)
# Out:
